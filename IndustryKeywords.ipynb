# %%
# INDUSTRY KEYWORDS (map of a map)

industries_keywords = {
    'Technology': ['AI', 'Cybersecurity', 'Blockchain', 'Software', 'Hardware', 'Semiconductors', 'Cloud', 'Robotics', 'Automation', 'Gadgets'],
    'Healthcare': ['Vaccines', 'Biotech', 'Pharmaceuticals', 'Hospitals', 'Clinics', 'Diagnostics', 'Therapy', 'Surgery', 'Medications', 'Nursing'],
    'Financial Services': ['Banking', 'Fintech', 'Stocks', 'Bonds', 'Insurance', 'Cryptocurrency', 'Investments', 'Trading', 'Interest', 'Loans'],
    'Energy': ['Oil', 'Gas', 'Solar', 'Wind', 'Nuclear', 'Renewable', 'Electricity', 'Hydro', 'Coal', 'Petroleum'],
    'Consumer Goods': ['Retail', 'Brands', 'Marketing', 'Ecommerce', 'Products', 'Customers', 'Trends', 'Packaging', 'Sales', 'Fashion'],
    'Industrial Manufacturing': ['Machinery', 'Logistics', 'Production', 'Supply', 'Robotics', 'Tools', 'Equipment', 'Assembly', 'Factories', 'Automation'],
    'Telecommunications': ['5G', 'Broadband', 'Networks', 'Wireless', 'Satellite', 'Spectrum', 'Data', 'Signals', 'Infrastructure', 'Fiber'],
    'Transportation': ['Airlines', 'Automotive', 'Shipping', 'Railways', 'Transit', 'Vehicles', 'Fuel', 'Roads', 'Traffic', 'Logistics'],
    'Real Estate': ['Housing', 'Mortgages', 'Property', 'Rentals', 'Zoning', 'Construction', 'Development', 'Markets', 'Sales', 'Investments'],
    'Agriculture': ['Crops', 'Farming', 'Livestock', 'Commodities', 'Irrigation', 'Soil', 'Harvest', 'Seeds', 'Fertilizer', 'Pesticides'],
    'Entertainment': ['Movies', 'Music', 'Gaming', 'Streaming', 'Media', 'Sports', 'Content', 'Celebrities', 'Theater', 'Events'],
    'Hospitality and Tourism': ['Hotels', 'Travel', 'Tourism', 'Resorts', 'Cruises', 'Restaurants', 'Visitors', 'Leisure', 'Bookings', 'Hospitality'],
    'Food and Beverage': ['Food', 'Drinks', 'Nutrition', 'Cuisine', 'Beverages', 'Ingredients', 'Snacks', 'Dining', 'Catering', 'Groceries'],
    'Education': ['Schools', 'Students', 'Teachers', 'Curriculum', 'Courses', 'Universities', 'Learning', 'Degrees', 'Classes', 'Exams'],
    'Aerospace and Defense': ['Aircraft', 'Space', 'Missiles', 'Satellites', 'Defense', 'Military', 'Weapons', 'Aviation', 'Security', 'Rockets'],
    'Environmental': ['Climate', 'Emissions', 'Recycling', 'Conservation', 'Ecology', 'Pollution', 'Biodiversity', 'Sustainability', 'Green', 'Ecosystems'],
    'Media and Publishing': ['Publishing', 'Journalism', 'Advertising', 'Content', 'News', 'Magazines', 'Newspapers', 'Authors', 'Broadcasting', 'Media'],
    'Mining and Metals': ['Mining', 'Metals', 'Minerals', 'Gold', 'Silver', 'Copper', 'Exploration', 'Extraction', 'Ore', 'Resources'],
    'Pharmaceuticals': ['Drugs', 'Medicine', 'Vaccines', 'Patents', 'Trials', 'Dosage', 'Treatment', 'Prescription', 'Generics', 'Research'],
    'Utilities': ['Electricity', 'Water', 'Gas', 'Power', 'Grid', 'Energy', 'Infrastructure', 'Rates', 'Supply', 'Distribution']
}

# Possible keywords to ues for the future
industries_keywords_technology = {
    'Technology': ['AI', 'Cybersecurity', 'Blockchain', 'Machine Learning', 'Quantum Computing', 'Edge Computing', 'Augmented Reality', 'Virtual Reality', 'Internet of Things', 'Data Science'],
    'Healthcare': ['Telemedicine', 'Wearables', 'Genomics', 'AI Diagnostics', 'Robotic Surgery', 'Digital Health Records', 'Health Apps', 'Precision Medicine', 'Medical Imaging', 'Bioinformatics'],
    'Financial Services': ['Digital Banking', 'Robo-Advisors', 'Blockchain', 'Cryptocurrencies', 'Digital Wallets', 'Mobile Payments', 'Insurtech', 'Risk Analytics', 'RegTech', 'Smart Contracts'],
    'Energy': ['Smart Grids', 'Battery Storage', 'Green Energy', 'Energy Efficiency', 'Solar Tech', 'Wind Tech', 'Biofuels', 'Carbon Capture', 'Electric Vehicles', 'Energy Analytics'],
    'Consumer Goods': ['Smart Home', 'IoT Devices', 'Ecommerce Platforms', 'Digital Payments', 'Wearables', 'Personalization', 'Subscription Services', 'AR Shopping', 'Delivery Tech', 'Supply Chain Tracking'],
    'Industrial Manufacturing': ['3D Printing', 'Digital Twin', 'Industrial IoT', 'Smart Factories', 'Automation', 'Predictive Maintenance', 'Drones', 'Advanced Robotics', 'Additive Manufacturing', 'AI-Driven Quality Control'],
    'Telecommunications': ['5G', 'Cloud Computing', 'Edge Networks', 'Fiber Optics', 'AI-Powered Network Management', 'Satellite Internet', 'VoIP', 'Spectrum Management', 'Signal Processing', 'IoT Connectivity'],
    'Transportation': ['Autonomous Vehicles', 'EV Charging', 'Urban Mobility', 'Smart Logistics', 'Fleet Management', 'Drones', 'Traffic Analytics', 'MaaS (Mobility as a Service)', 'EV Batteries', 'Hyperloop'],
    'Real Estate': ['PropTech', 'Smart Buildings', 'Virtual Tours', 'Digital Leasing', 'IoT Sensors', 'Property Management Software', 'Data-Driven Valuations', '3D Modeling', 'Augmented Reality', 'Blockchain in Real Estate'],
    'Agriculture': ['AgriTech', 'Precision Farming', 'Drone Surveillance', 'Hydroponics', 'Smart Irrigation', 'Agricultural Drones', 'Soil Sensors', 'Genetically Modified Crops', 'Crop Monitoring', 'AI Pest Control'],
    'Entertainment': ['Streaming Platforms', 'VR Gaming', 'Digital Concerts', 'Interactive Media', 'Blockchain in Media', 'Augmented Reality Experiences', 'AI Content Creation', 'Cloud Gaming', 'Social Media Integration', 'eSports'],
    'Hospitality and Tourism': ['Booking Platforms', 'Smart Rooms', 'Virtual Tours', 'Digital Check-In', 'Contactless Payment', 'AI Chatbots', 'Data-Driven Marketing', 'IoT in Hotels', 'Experience Personalization', 'Travel Tech'],
    'Food and Beverage': ['Food Delivery Apps', 'Meal Kits', 'Cloud Kitchens', 'Food Tech', 'AI in Recipes', 'Smart Packaging', 'Nutritional Analytics', 'Blockchain in Supply Chain', 'Plant-Based Foods', 'Lab-Grown Meat'],
    'Education': ['EdTech', 'Online Learning Platforms', 'Virtual Classrooms', 'AI Tutors', 'Gamification', 'Learning Analytics', 'Digital Content', 'Adaptive Learning', 'MOOCs', 'Collaborative Tools'],
    'Aerospace and Defense': ['Space Exploration Tech', 'Hypersonic Aircraft', 'AI-Driven Defense', 'Cybersecurity', 'Unmanned Aerial Vehicles', 'Satellites', 'Rocket Technology', 'Space Tourism', 'Drone Warfare', 'Orbital Satellites'],
    'Environmental': ['CleanTech', 'Carbon Offsetting', 'Environmental Sensors', 'Climate Data', 'Recycling Technologies', 'GreenTech', 'AI Climate Modeling', 'Pollution Monitoring', 'Waste Management', 'Renewable Resources'],
    'Media and Publishing': ['Digital Journalism', 'SEO', 'Content Algorithms', 'Online Subscriptions', 'Social Media', 'Digital Publishing', 'Video Platforms', 'Content Monetization', 'VR/AR Media', 'AI-Generated Content'],
    'Mining and Metals': ['Mining Automation', 'Ore Sorting', 'Mineral Detection', 'Smart Mining', 'Drones', 'Data-Driven Exploration', 'Blockchain Tracking', 'Recycling Tech', 'Environmental Sensors', '3D Mapping'],
    'Pharmaceuticals': ['Digital Drug Development', 'Wearables for Trials', 'AI in Drug Discovery', 'Genetic Therapies', 'Biotechnology', 'Drug Delivery Systems', 'Digital Biomarkers', 'Remote Trials', 'AR in Training', 'Data-Driven Research'],
    'Utilities': ['Smart Meters', 'Grid Management', 'Demand Response', 'Energy Management Systems', 'AI Energy Forecasting', 'Blockchain for Energy Trading', 'Battery Storage', 'Electric Vehicle Charging', 'Distributed Energy', 'Renewable Grid Integration']
}

industry_keyword_map = {}
for industry, keywords in industries_keywords.items():
  industry_keyword_map[industry] = {}
  for keyword in keywords:
    industry_keyword_map[industry][keyword] = 0

# Sample data to populate the map
data = """
AI: 150
API: 45
agile: 25
algorithm: 30
analytics: 60
app: 120
automation: 50
backend: 35
ecology: 40
blockchain: 55
branding: 20
cloud: 80
collaboration: 45
community: 30
computing: 25
cybersecurity: 70
data: 100
design: 90
devops: 40
disrupt: 15
ecosystem: 20
funding: 35
growth: 60
innovation: 50
investment: 40
IoT: 55
launch: 25
machine: 65
market: 45
MVP: 30
networking: 25
pitch: 20
platform: 85
product: 95
prototype: 30
scalable: 40
software: 90
solution: 85
startup: 100
strategy: 60
technology: 100
UI: 50
UX: 50
user: 70
venture: 40
web: 60
"""

for line in data.splitlines():
  parts = line.split(':')
  if len(parts) == 2:
    keyword = parts[0].strip()
    count = int(parts[1].strip())

    for industry in industry_keyword_map:
      if keyword.lower() in [k.lower() for k in industry_keyword_map[industry]]:
        for k in industry_keyword_map[industry]:
          if keyword.lower() == k.lower():
            industry_keyword_map[industry][k] = count
            break

industry_keyword_map
# Out:
# {'Technology': {'AI': 150,
#   'Cybersecurity': 70,
#   'Blockchain': 55,
#   'Software': 90,
#   'Hardware': 0,
#   'Semiconductors': 0,
#   'Cloud': 80,
#   'Robotics': 0,
#   'Automation': 50,
#   'Gadgets': 0},
#  'Healthcare': {'Vaccines': 0,
#   'Biotech': 0,
#   'Pharmaceuticals': 0,
#   'Hospitals': 0,
#   'Clinics': 0,
#   'Diagnostics': 0,
#   'Therapy': 0,
#   'Surgery': 0,
#   'Medications': 0,
#   'Nursing': 0},
#  'Financial Services': {'Banking': 0,
#   'Fintech': 0,
#   'Stocks': 0,
#   'Bonds': 0,
#   'Insurance': 0,
#   'Cryptocurrency': 0,
#   'Investments': 0,
#   'Trading': 0,
#   'Interest': 0,
#   'Loans': 0},
#  'Energy': {'Oil': 0,
#   'Gas': 0,
#   'Solar': 0,
#   'Wind': 0,
#   'Nuclear': 0,
#   'Renewable': 0,
#   'Electricity': 0,
#   'Hydro': 0,
#   'Coal': 0,
#   'Petroleum': 0},
#  'Consumer Goods': {'Retail': 0,
#   'Brands': 0,
#   'Marketing': 0,
#   'Ecommerce': 0,
#   'Products': 0,
#   'Customers': 0,
#   'Trends': 0,
#   'Packaging': 0,
# ...
